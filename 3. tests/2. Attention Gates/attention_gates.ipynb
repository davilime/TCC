# %%
from google.colab import drive

# Monta o Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install hiddenlayer
# Out:
# Collecting hiddenlayer
#   Downloading hiddenlayer-0.3-py3-none-any.whl.metadata (703 bytes)
# Downloading hiddenlayer-0.3-py3-none-any.whl (19 kB)
# Installing collected packages: hiddenlayer
# Successfully installed hiddenlayer-0.3

# %%
# !git clone https://github.com/niccolo246/Advanced_nnUNet
# Out:
# Cloning into 'Advanced_nnUNet'...
# remote: Enumerating objects: 586, done.
# remote: Counting objects: 100% (586/586), done.
# remote: Compressing objects: 100% (391/391), done.
# remote: Total 586 (delta 238), reused 523 (delta 190), pack-reused 0 (from 0)
# Receiving objects: 100% (586/586), 704.49 KiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (238/238), done.

# %%
# %cd
# Out:
# /root

# %%
# %cd /content
# Out:
# /content

# %%
# !dir
# Out:
# Advanced_nnUNet  drive	sample_data

# %%
# %cd Advanced_nnUNet
# Out:
# /content/Advanced_nnUNet

# %%
# !dir
# Out:
# nnunet		 nnUNet_LICENSE  scratch.py  setup.py
# nnunet.egg-info  README.md	 setup.cfg

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
# !pip install torch>=1.6.0 tqdm dicom2nifti scikit-image>=0.14 medpy scipy batchgenerators>=0.23 numpy SimpleITK pandas requests nibabel tifffile matplotlib

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/Advanced_nnUNet
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.6.0a in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (4.67.1)
# Requirement already satisfied: dicom2nifti in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.6.2)
# Requirement already satisfied: scikit-image>=0.14 in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (0.25.2)
# Requirement already satisfied: medpy in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (0.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (1.16.2)
# Requirement already satisfied: batchgenerators>=0.23 in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (0.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.0.2)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2.32.4)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (5.3.2)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (2025.10.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from extended_nnunet==1.7.0) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.23->extended_nnunet==1.7.0) (11.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.23->extended_nnunet==1.7.0) (1.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.23->extended_nnunet==1.7.0) (1.0.0)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.23->extended_nnunet==1.7.0) (1.1.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.23->extended_nnunet==1.7.0) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14->extended_nnunet==1.7.0) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14->extended_nnunet==1.7.0) (2.37.0)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14->extended_nnunet==1.7.0) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14->extended_nnunet==1.7.0) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0a->extended_nnunet==1.7.0) (3.4.0)
# Requirement already satisfied: pydicom>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dicom2nifti->extended_nnunet==1.7.0) (3.0.1)
# Requirement already satisfied: python-gdcm in /usr/local/lib/python3.12/dist-packages (from dicom2nifti->extended_nnunet==1.7.0) (3.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->extended_nnunet==1.7.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->extended_nnunet==1.7.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->extended_nnunet==1.7.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->extended_nnunet==1.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->extended_nnunet==1.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->extended_nnunet==1.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->extended_nnunet==1.7.0) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->extended_nnunet==1.7.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0a->extended_nnunet==1.7.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0a->extended_nnunet==1.7.0) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->batchgenerators>=0.23->extended_nnunet==1.7.0) (1.5.2)
# Collecting argparse (from unittest2->batchgenerators>=0.23->extended_nnunet==1.7.0)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators>=0.23->extended_nnunet==1.7.0) (1.4.0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.12/dist-packages (from traceback2->unittest2->batchgenerators>=0.23->extended_nnunet==1.7.0) (1.0.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse, extended_nnunet
#   Running setup.py develop for extended_nnunet
# Successfully installed argparse-1.4.0 extended_nnunet-1.7.0

# %%
import os
os.environ["nnUNet_raw_data_base"] = "/content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_raw_data_base"
os.environ["nnUNet_preprocessed"] = "/content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed"
os.environ["RESULTS_FOLDER"] = "/content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_results"

# %%
# !export nnUNet_raw_data_base="/content/drive/MyDrive/TCC_1/1.Data/nnU-net_format/subset_50/nnUNet_raw_data_base"
# !export nnUNet_preprocessed="/content/drive/MyDrive/TCC_1/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed"
# !export RESULTS_FOLDER="/content/drive/MyDrive/TCC_1/1.Data/nnU-net_format/subset_50/nnUNet_results"

# %%
import json
from collections import OrderedDict
from pathlib import Path
from batchgenerators.utilities.file_and_folder_operations import maybe_mkdir_p

# ------------------- CONFIGURAÇÃO -------------------
dataset_dir = Path("/content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MyBraTS")
imagesTr = dataset_dir / "imagesTr"
labelsTr = dataset_dir / "labelsTr"
imagesTs = dataset_dir / "imagesTs"

nnunet_dataset_name = "MyBraTS"
nnunet_dataset_id = 1
dataset_name = f"Task{nnunet_dataset_id:03d}_{nnunet_dataset_name}"
maybe_mkdir_p(dataset_dir)

# ------------------- CASOS DE TREINO E TESTE -------------------
train_cases = sorted({f.stem[:-9] for f in imagesTr.glob("*_0000.nii.gz")})
test_cases = sorted({f.stem[:-9] for f in imagesTs.glob("*_0000.nii.gz")})

# ------------------- LABELS E MODALIDADES -------------------
modalities = {
    "0": "T1",
    "1": "T1C",
    "2": "T2W",
    "3": "T2F"
}

labels_dict = {
    "0": "background",
    "1": "NETC",
    "2": "SNFH",
    "3": "ET",
    "4": "RC"
}

# ------------------- MONTAR LISTA DE TREINO -------------------
training_list = [
    {
        "image": f"./imagesTr/{case}.nii.gz",
        "label": f"./labelsTr/{case}.nii.gz"
    }
    for case in train_cases
]

# ------------------- MONTAR LISTA DE TESTE -------------------
test_list = [f"./imagesTs/{case}.nii.gz" for case in test_cases]

# ------------------- CRIAR JSON -------------------
json_dict = OrderedDict()
json_dict["name"] = dataset_name
json_dict["description"] = "Dataset MyBraTS subset 50 para nnU-Net v1"
json_dict["tensorImageSize"] = "4D"
json_dict["reference"] = "https://www.synapse.org/Synapse:syn53708249/wiki/627500"
json_dict["licence"] = "see https://www.synapse.org/Synapse:syn53708249/wiki/627508"
json_dict["release"] = "0.0"
json_dict["modality"] = modalities
json_dict["labels"] = labels_dict
json_dict["numTraining"] = len(train_cases)
json_dict["numTest"] = len(test_cases)
json_dict["training"] = training_list
json_dict["test"] = test_list

# ------------------- SALVAR -------------------
output_json_path = dataset_dir / "dataset.json"
with open(output_json_path, "w") as f:
    json.dump(json_dict, f, indent=4)

print(f"✅ JSON criado em: {output_json_path}")
print(f"Treino: {len(train_cases)} casos | Teste: {len(test_cases)} casos")
# Out:
# ✅ JSON criado em: /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_raw_data_base/nnUNet_raw_data/Task001_MyBraTS/dataset.json
# Treino: 40 casos | Teste: 10 casos

# %%
# !nnUNet_plan_and_preprocess -t 1 -pl3d ExperimentPlanner3DSpatialSingleAttentionUNet_v21 --verify_dataset_integrity
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# Verifying training set
# checking case BraTS-GLI-00008-100
# checking case BraTS-GLI-00533-100
# checking case BraTS-GLI-02068-100
# checking case BraTS-GLI-02076-100
# checking case BraTS-GLI-02160-100
# checking case BraTS-GLI-02170-100
# checking case BraTS-GLI-02185-100
# checking case BraTS-GLI-02208-100
# checking case BraTS-GLI-02218-100
# checking case BraTS-GLI-02251-100
# checking case BraTS-GLI-02338-100
# checking case BraTS-GLI-02339-100
# checking case BraTS-GLI-02375-100
# checking case BraTS-GLI-02410-100
# checking case BraTS-GLI-02420-100
# checking case BraTS-GLI-02421-100
# checking case BraTS-GLI-02478-100
# checking case BraTS-GLI-02487-100
# checking case BraTS-GLI-02488-100
# checking case BraTS-GLI-02503-100
# checking case BraTS-GLI-02580-100
# checking case BraTS-GLI-02615-100
# checking case BraTS-GLI-02618-100
# checking case BraTS-GLI-02624-100
# checking case BraTS-GLI-02636-100
# checking case BraTS-GLI-02658-100
# checking case BraTS-GLI-02698-100
# checking case BraTS-GLI-02745-100
# checking case BraTS-GLI-02756-100
# checking case BraTS-GLI-02787-100
# checking case BraTS-GLI-02817-100
# checking case BraTS-GLI-02872-100
# checking case BraTS-GLI-02890-100
# checking case BraTS-GLI-02914-100
# checking case BraTS-GLI-02932-100
# checking case BraTS-GLI-02941-100
# checking case BraTS-GLI-02953-100
# checking case BraTS-GLI-03010-100
# checking case BraTS-GLI-03014-100
# checking case BraTS-GLI-03062-100
# Verifying label values
# Expected label values are [0, 1, 2, 3, 4]
# Labels OK
# Verifying test set
# Dataset OK
# BraTS-GLI-00008-100
# BraTS-GLI-02068-100
# BraTS-GLI-02160-100
# BraTS-GLI-02218-100
# BraTS-GLI-02338-100
# BraTS-GLI-02375-100
# BraTS-GLI-02420-100
# BraTS-GLI-02185-100
# before crop: (4, 182, 218, 182) after crop: (4, 125, 173, 138) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 144, 177, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 140, 153, 134) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 147, 171, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 142, 177, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 148, 152, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 156, 172, 144) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 151, 185, 142) spacing: [1. 1. 1.]
#
# BraTS-GLI-00533-100
# BraTS-GLI-02251-100
# BraTS-GLI-02339-100
# BraTS-GLI-02410-100
# BraTS-GLI-02421-100
# BraTS-GLI-02076-100
# BraTS-GLI-02208-100
# before crop: (4, 182, 218, 182) after crop: (4, 142, 180, 137) spacing: [1. 1. 1.]
#
# BraTS-GLI-02170-100
# before crop: (4, 182, 218, 182) after crop: (4, 144, 166, 137) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 150, 170, 137) spacing: [1. 1. 1.]
#
# BraTS-GLI-02478-100
# before crop: (4, 182, 218, 182) after crop: (4, 141, 177, 138) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 148, 184, 132) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 153, 175, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 131, 171, 124) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 141, 166, 130) spacing: [1. 1. 1.]
#
# BraTS-GLI-02488-100
# before crop: (4, 182, 218, 182) after crop: (4, 136, 154, 141) spacing: [1. 1. 1.]
#
# BraTS-GLI-02580-100
# BraTS-GLI-02618-100
# BraTS-GLI-02636-100
# BraTS-GLI-02698-100
# BraTS-GLI-02756-100
# BraTS-GLI-02817-100
# before crop: (4, 182, 218, 182) after crop: (4, 137, 160, 133) spacing: [1. 1. 1.]
#
# BraTS-GLI-02487-100
# before crop: (4, 182, 218, 182) after crop: (4, 138, 168, 132) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 162, 186, 148) spacing: [1. 1. 1.]
#
# BraTS-GLI-02503-100
# before crop: (4, 182, 218, 182) after crop: (4, 151, 178, 140) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 132, 153, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 145, 174, 130) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 139, 183, 147) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 136, 163, 146) spacing: [1. 1. 1.]
#
# BraTS-GLI-02615-100
# BraTS-GLI-02658-100
# before crop: (4, 182, 218, 182) after crop: (4, 134, 160, 130) spacing: [1. 1. 1.]
#
# BraTS-GLI-02872-100
# BraTS-GLI-02624-100
# BraTS-GLI-02787-100
# BraTS-GLI-02890-100
# before crop: (4, 182, 218, 182) after crop: (4, 133, 158, 140) spacing: [1. 1. 1.]
#
# BraTS-GLI-02932-100
# before crop: (4, 182, 218, 182) after crop: (4, 160, 181, 145) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 140, 182, 139) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 140, 171, 132) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 137, 191, 137) spacing: [1. 1. 1.]
#
# BraTS-GLI-02953-100
# before crop: (4, 182, 218, 182) after crop: (4, 143, 177, 137) spacing: [1. 1. 1.]
#
# BraTS-GLI-02745-100
# before crop: (4, 182, 218, 182) after crop: (4, 147, 183, 148) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 146, 183, 144) spacing: [1. 1. 1.]
#
# BraTS-GLI-03014-100
# before crop: (4, 182, 218, 182) after crop: (4, 141, 194, 150) spacing: [1. 1. 1.]
#
# BraTS-GLI-02914-100
# BraTS-GLI-02941-100
# before crop: (4, 182, 218, 182) after crop: (4, 142, 187, 144) spacing: [1. 1. 1.]
#
# BraTS-GLI-03010-100
# before crop: (4, 182, 218, 182) after crop: (4, 138, 197, 143) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 145, 187, 136) spacing: [1. 1. 1.]
#
# before crop: (4, 182, 218, 182) after crop: (4, 135, 186, 143) spacing: [1. 1. 1.]
#
# BraTS-GLI-03062-100
# before crop: (4, 182, 218, 182) after crop: (4, 138, 176, 132) spacing: [1. 1. 1.]
#
#
#
#
#  Task001_MyBraTS
# number of threads:  (8, 8)
#
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# Are we using the nonzero mask for normalization? OrderedDict({0: True, 1: True, 2: True, 3: True})
# the median shape of the dataset is  [141.5 176.5 137.5]
# the max shape in the dataset is  [162. 197. 150.]
# the min shape in the dataset is  [125. 152. 124.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [141.5 176.5 137.5]
# generating configuration for 3d_fullres
# 1 64 5 [71. 88. 69.]
# 2 128 5 [35.5 44.  34.5]
# 3 256 5 [17.75 22.   17.25]
# 4 320 5 [ 8.875 11.     8.625]
# 5 320 5 [4.4375 5.5    4.3125]
# 1 64 6 [71. 88. 69.]
# 2 128 6 [35.5 44.  34.5]
# 3 256 6 [17.75 22.   17.25]
# 4 320 6 [ 8.875 11.     8.625]
# 1 64 5 [80. 96. 64.]
# 2 128 5 [40. 48. 32.]
# 3 256 5 [20. 24. 16.]
# 4 320 5 [10. 12.  8.]
# 5 320 5 [5. 6. 4.]
# 1 64 6 [80. 96. 64.]
# 2 128 6 [40. 48. 32.]
# 3 256 6 [20. 24. 16.]
# 4 320 6 [10. 12.  8.]
# 1 64 5 [64. 96. 64.]
# 2 128 5 [32. 48. 32.]
# 3 256 5 [16. 24. 16.]
# 4 320 5 [ 8. 12.  8.]
# 5 320 5 [4. 6. 4.]
# 1 64 6 [64. 96. 64.]
# 2 128 6 [32. 48. 32.]
# 3 256 6 [16. 24. 16.]
# 4 320 6 [ 8. 12.  8.]
# 1 64 5 [64. 80. 64.]
# 2 128 5 [32. 40. 32.]
# 3 256 5 [16. 20. 16.]
# 4 320 5 [ 8. 10.  8.]
# 5 320 5 [4. 5. 4.]
# 1 64 6 [64. 80. 64.]
# 2 128 6 [32. 40. 32.]
# 3 256 6 [16. 20. 16.]
# 4 320 6 [ 8. 10.  8.]
# 1 64 5 [64. 80. 56.]
# 2 128 5 [32. 40. 28.]
# 3 256 5 [16. 20. 14.]
# 4 320 5 [ 8. 10.  7.]
# 5 320 5 [4. 5. 7.]
# 1 64 6 [64. 80. 56.]
# 2 128 6 [32. 40. 28.]
# 3 256 6 [16. 20. 14.]
# 4 320 6 [ 8. 10.  7.]
# 1 64 5 [64. 64. 56.]
# 2 128 5 [32. 32. 28.]
# 3 256 5 [16. 16. 14.]
# 4 320 5 [8. 8. 7.]
# 5 320 5 [4. 4. 7.]
# 1 64 6 [64. 64. 56.]
# 2 128 6 [32. 32. 28.]
# 3 256 6 [16. 16. 14.]
# 4 320 6 [8. 8. 7.]
# 1 64 5 [56. 64. 56.]
# 2 128 5 [28. 32. 28.]
# 3 256 5 [14. 16. 14.]
# 4 320 5 [7. 8. 7.]
# 5 320 5 [7. 4. 7.]
# 1 64 6 [56. 64. 56.]
# 2 128 6 [28. 32. 28.]
# 3 256 6 [14. 16. 14.]
# 4 320 6 [7. 8. 7.]
# 1 64 5 [56. 64. 48.]
# 2 128 5 [28. 32. 24.]
# 3 256 5 [14. 16. 12.]
# 4 320 5 [7. 8. 6.]
# 5 320 5 [7. 4. 6.]
# 1 64 6 [56. 64. 48.]
# 2 128 6 [28. 32. 24.]
# 3 256 6 [14. 16. 12.]
# 4 320 6 [7. 8. 6.]
# 1 64 5 [48. 64. 48.]
# 2 128 5 [24. 32. 24.]
# 3 256 5 [12. 16. 12.]
# 4 320 5 [6. 8. 6.]
# 5 320 5 [6. 4. 6.]
# 1 64 6 [48. 64. 48.]
# 2 128 6 [24. 32. 24.]
# 3 256 6 [12. 16. 12.]
# 4 320 6 [6. 8. 6.]
# {0: {'batch_size': 2, 'num_pool_per_axis': [4, 5, 4], 'patch_size': array([ 96, 128,  96]), 'median_patient_size_in_voxels': array([142, 176, 138]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': np.False_, 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 1]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'num_blocks_encoder': (2, 2, 2, 2, 2, 2), 'num_blocks_decoder': (2, 2, 2, 2, 2)}}
# transpose forward [np.int64(0), 1, 2]
# transpose backward [np.int64(0), np.int64(1), np.int64(2)]
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# using nonzero mask for normalization
# Are we using the nonzero mask for normalization? OrderedDict({0: True, 1: True, 2: True, 3: True})
# the median shape of the dataset is  [141.5 176.5 137.5]
# the max shape in the dataset is  [162. 197. 150.]
# the min shape in the dataset is  [125. 152. 124.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [141.5 176.5 137.5]
# [{'batch_size': 106, 'num_pool_per_axis': [5, 5], 'patch_size': array([192, 160]), 'median_patient_size_in_voxels': array([142, 176, 138]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'pool_op_kernel_sizes': [[2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'do_dummy_2D_data_aug': False}]
# Initializing to run preprocessing
# npz folder: /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_raw_data_base/nnUNet_cropped_data/Task001_MyBraTS
# output_folder: /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 144, 177, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 144, 177, 136)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 148, 152, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 148, 152, 130)}
#
# normalization...
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 153, 134)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 153, 134)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 147, 171, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 147, 171, 139)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 156, 172, 144)}
# after: no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 125, 173, 138)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 125, 173, 138)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 142, 177, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 142, 177, 136)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 156, 172, 144)}
#
# normalization...
# normalization...
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 151, 185, 142)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 151, 185, 142)}
#
# normalization...
# normalization done
# normalization done
# normalization done
# normalization done
# normalization done
# normalization done
# normalization done
# 1 74
# 2 10000
# 1 3261
# normalization done
# 2 10000
# 3 10000
# 2 10000
# 3 217
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02375-100.npz
# 3 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02338-100.npz
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02068-100.npz
# 2 3913
# 2 10000
# 2 6976
# 3 880
# 3 135
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02420-100.npz
# 4 1816
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-00008-100.npz
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02218-100.npz
# 2 10000
# 3 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02185-100.npz
# 1 74
# 2 10000
# 3 3247
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02160-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 148, 184, 132)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 148, 184, 132)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 150, 170, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 150, 170, 137)}
#
# normalization...
# normalization done
# normalization done
# 1 571
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 131, 171, 124)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 131, 171, 124)}
#
# normalization...
# 2 10000
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 142, 180, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 142, 180, 137)}
#
# 3 10000
# normalization...
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02410-100.npz
# 2 10000
# 3 1915
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02339-100.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 144, 166, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 144, 166, 137)}
#
# normalization...
# normalization done
# 1 4
# 2 10000
# 1 2971
# 3 10000
# 2 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02076-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 153, 175, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 153, 175, 140)}
#
# normalization...
# 3 10000
# normalization done
# 4 2059
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-00533-100.npz
# normalization done
# 1 351
# 2 10000
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 177, 138)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 177, 138)}
#
# normalization...
# 3 9614
# 4 6549
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02251-100.npz
# 1 10000
# 2 10000
# normalization done
# 3 10000
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 166, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 166, 130)}
#
# normalization...
# 4 3854
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02421-100.npz
# 1 2368
# normalization done
# 2 2026
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02208-100.npz
# 1 4204
# 2 10000
# 3 2617
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02170-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 154, 141)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 154, 141)}
#
# normalization...
# normalization done
# 2 10000
# 3 4107
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02478-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 160, 133)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 160, 133)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 168, 132)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 168, 132)}
#
# normalization...
# normalization done
# 1 5289
# 2 10000
# 3 10000
# 4 4494
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02488-100.npz
# normalization done
# 2 10000
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 151, 178, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 151, 178, 140)}
#
# 3 38
# normalization...
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02580-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 132, 153, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 132, 153, 130)}
#
# normalization...
# normalization done
# normalization done
# 2 5364
# 1 1294
# 2 7264
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 162, 186, 148)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 162, 186, 148)}
#
# normalization...
# 4 3680
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02636-100.npz
# 3 5182
# 4 3
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02618-100.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 139, 183, 147)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 139, 183, 147)}
#
# normalization...
# 2 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02698-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 145, 174, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 145, 174, 130)}
#
# normalization...
# normalization done
# normalization done
# 2 9146
# 2 10000
# 3 3076
# 3 2420
# 4 5657
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02756-100.npz
# 4 1046
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02817-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 136, 163, 146)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 136, 163, 146)}
#
# normalization...
# normalization done
# 1 3450
# 2 10000
# 3 5978
# 4 12
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02487-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 134, 160, 130)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 134, 160, 130)}
#
# normalization...
# normalization done
# 2 10000
# 3 3178
# 4 6079
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02503-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 133, 158, 140)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 133, 158, 140)}
#
# normalization...
# normalization done
# 1 1
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 160, 181, 145)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 160, 181, 145)}
#
# normalization...
# 2 10000
# 3 9946
# 4 6702
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02615-100.npz
# normalization done
# 2 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02658-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 171, 132)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 171, 132)}
#
# normalization...
# normalization done
# 2 10000
# 3 10000
# 4 2156
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02624-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 141, 194, 150)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 141, 194, 150)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 140, 182, 139)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 140, 182, 139)}
#
# normalization...
# normalization done
# 1 106
# 2 8491
# 3 8380
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02745-100.npz
# normalization done
# 1 916
# 2 10000
# 3 10000
# 4 7537
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02872-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 137, 191, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 137, 191, 137)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 143, 177, 137)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 143, 177, 137)}
#
# normalization...
# 2 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02787-100.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 147, 183, 148)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 147, 183, 148)}
#
# normalization...
# 1 60
# 2 10000
# 3 1192
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02890-100.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 146, 183, 144)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 146, 183, 144)}
#
# normalization...
# normalization done
# 2 1021
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02932-100.npz
# 2 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02953-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 142, 187, 144)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 142, 187, 144)}
#
# normalization...
# normalization done
# 2 10000
# 3 5910
# 4 2070
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-03014-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 197, 143)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 197, 143)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# 3 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02914-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 135, 186, 143)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 135, 186, 143)}
#
# normalization...
# normalization done
# 2 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-03010-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 145, 187, 136)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 145, 187, 136)}
#
# normalization...
# normalization done
# 1 935
# 2 10000
# 3 5299
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-02941-100.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (4, 138, 176, 132)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (4, 138, 176, 132)}
#
# normalization...
# normalization done
# 1 4656
# 2 10000
# 3 10000
# 4 10000
# saving:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_2D_stage0/BraTS-GLI-03062-100.npz

# %%
# !nnUNet_train 3d_fullres nnUNetTrainerV2_SpatialSingleAttentionUNet 1 2 -p nnUNetPlans_SpatialSingleAttentionUNet_v2.1
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.nnUNet_variants.architectural_variants.nnUNetTrainerV2_GenericSpatialSingleAttentionUNet.nnUNetTrainerV2_SpatialSingleAttentionUNet'>
# For that I will be using the following configuration:
# num_classes:  4
# modalities:  {0: 'T1', 1: 'T1C', 2: 'T2W', 3: 'T2F'}
# use_mask_for_norm OrderedDict({0: True, 1: True, 2: True, 3: True})
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict({0: 'nonCT', 1: 'nonCT', 2: 'nonCT', 3: 'nonCT'})
# stages...
#
# stage:  0
# {'batch_size': 2, 'num_pool_per_axis': [4, 5, 4], 'patch_size': array([ 96, 128,  96]), 'median_patient_size_in_voxels': array([142, 176, 138]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': np.False_, 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [1, 2, 1]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'num_blocks_encoder': (2, 2, 2, 2, 2, 2), 'num_blocks_decoder': (2, 2, 2, 2, 2)}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1
# ###############################################
# loading dataset
# loading all case properties
# 2025-10-19 13:20:02.448550: Using splits from existing split file: /content/drive/MyDrive/TCC/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/splits_final.pkl
# 2025-10-19 13:20:02.462833: The split file contains 5 splits.
# 2025-10-19 13:20:02.466215: Desired fold for training: 2
# 2025-10-19 13:20:02.470186: This split has 32 training and 8 validation cases.
# unpacking dataset
# done
# 50
# 2025-10-19 13:20:05.489136: lr: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# /content/Advanced_nnUNet/nnunet/training/network_training/network_trainer.py:404: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.amp_grad_scaler = GradScaler()
# /content/Advanced_nnUNet/nnunet/network_architecture/custom_modules/conv_blocks.py:535: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert batch_size == g.size(0)
# 2025-10-19 13:21:36.345899: Unable to plot network architecture:
# 2025-10-19 13:21:36.444451: module 'torch.onnx' has no attribute '_optimize_trace'
# 2025-10-19 13:21:36.499980:
# printing the network instead:
#
# 2025-10-19 13:21:36.554917: GenericSpatialSingleAttentionUNet(
#   (encoder): GenericAttentionUNetEncoder(
#     (stages): ModuleList(
#       (0): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(4, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (2): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (3): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (4): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (5): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 2, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 2, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): GenericChannelSpatialAttentionUNetDecoder(
#     (gating): UnetGridGatingSignal3(
#       (conv1): Sequential(
#         (0): Conv3d(320, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (1): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (segmentation_output): Conv3d(32, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (atten): ModuleList(
#       (0): SpatialSingleAttentionBlock(
#         (spatial_block): SpatialAttentionBlock3D(
#           (conv_x): Sequential(
#             (0): Conv1d(640, 320, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(320, 320, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#           (conv_g): Sequential(
#             (0): Conv1d(640, 320, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(320, 320, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (gate_block_1): GridAttentionBlock3D(
#           (theta): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (phi): Conv3d(320, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (psi): Conv3d(320, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (W): Sequential(
#             (0): Conv3d(320, 320, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             (1): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (1): SpatialSingleAttentionBlock(
#         (spatial_block): SpatialAttentionBlock3D(
#           (conv_x): Sequential(
#             (0): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#           (conv_g): Sequential(
#             (0): Conv1d(640, 256, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (gate_block_1): GridAttentionBlock3D(
#           (theta): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (phi): Conv3d(320, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (psi): Conv3d(256, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (W): Sequential(
#             (0): Conv3d(256, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             (1): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (2): SpatialSingleAttentionBlock(
#         (spatial_block): SpatialAttentionBlock3D(
#           (conv_x): Sequential(
#             (0): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#           (conv_g): Sequential(
#             (0): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (gate_block_1): GridAttentionBlock3D(
#           (theta): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (phi): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (psi): Conv3d(128, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (W): Sequential(
#             (0): Conv3d(128, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             (1): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (3): SpatialSingleAttentionBlock(
#         (spatial_block): SpatialAttentionBlock3D(
#           (conv_x): Sequential(
#             (0): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#           (conv_g): Sequential(
#             (0): Conv1d(256, 64, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (gate_block_1): GridAttentionBlock3D(
#           (theta): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (phi): Conv3d(128, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (psi): Conv3d(64, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (W): Sequential(
#             (0): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             (1): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (4): SpatialSingleAttentionBlock(
#         (spatial_block): SpatialAttentionBlock3D(
#           (conv_x): Sequential(
#             (0): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#           (conv_g): Sequential(
#             (0): Conv1d(128, 32, kernel_size=(1,), stride=(1,))
#             (1): LeakyReLU(negative_slope=0.01)
#             (2): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#             (3): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (gate_block_1): GridAttentionBlock3D(
#           (theta): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (phi): Conv3d(64, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (psi): Conv3d(32, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (W): Sequential(
#             (0): Conv3d(32, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             (1): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           )
#         )
#       )
#     )
#     (tus): ModuleList(
#       (0): ConvTranspose3d(320, 320, kernel_size=(1, 2, 1), stride=(1, 2, 1), bias=False)
#       (1): ConvTranspose3d(320, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#       (2): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#       (3): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#       (4): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     )
#     (stages): ModuleList(
#       (0): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (2): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (3): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#       (4): StackedConvLayers(
#         (convs): Sequential(
#           (0): ConvDropoutNormReLU(
#             (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#           (1): ConvDropoutNormReLU(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (do): Identity()
#             (norm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (nonlin): LeakyReLU(negative_slope=0.01, inplace=True)
#             (all): Sequential(
#               (0): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               (1): Identity()
#               (2): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#               (3): LeakyReLU(negative_slope=0.01, inplace=True)
#             )
#           )
#         )
#       )
#     )
#     (deep_supervision_outputs): ModuleList(
#       (0): Conv3d(320, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (1): Conv3d(256, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (2): Conv3d(128, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (3): Conv3d(64, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     )
#   )
# )
# 2025-10-19 13:21:36.788984:
#
# 2025-10-19 13:21:37.088075:
# epoch:  0
# /content/Advanced_nnUNet/nnunet/training/network_training/nnUNetTrainerV2.py:246: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 2025-10-19 13:39:23.138496: train loss : 0.0762
# 2025-10-19 13:39:57.390995: validation loss: -0.0934
# 2025-10-19 13:39:57.502041: Average global foreground Dice: [np.float32(0.0), np.float32(0.592), np.float32(0.5352), np.float32(0.5576)]
# 2025-10-19 13:39:57.640095: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 13:40:04.092547: lr: 0.00982
# 2025-10-19 13:40:04.130934: This epoch took 1106.949870 s
#
# 2025-10-19 13:40:04.161705:
# epoch:  1
# 2025-10-19 13:58:03.232428: train loss : -0.1847
# 2025-10-19 13:58:38.765541: validation loss: -0.1555
# 2025-10-19 13:58:38.934780: Average global foreground Dice: [np.float32(1e-04), np.float32(0.6846), np.float32(0.6389), np.float32(0.6385)]
# 2025-10-19 13:58:39.100026: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 13:58:46.249038: lr: 0.009639
# 2025-10-19 13:58:48.290656: saving checkpoint...
# 2025-10-19 13:59:07.312272: done, saving took 20.99 seconds
# 2025-10-19 13:59:08.465874: This epoch took 1144.259125 s
#
# 2025-10-19 13:59:08.498884:
# epoch:  2
# 2025-10-19 14:16:12.084290: train loss : -0.2593
# 2025-10-19 14:16:58.304419: validation loss: -0.1515
# 2025-10-19 14:16:58.503618: Average global foreground Dice: [np.float32(0.1262), np.float32(0.7157), np.float32(0.6697), np.float32(0.5467)]
# 2025-10-19 14:16:58.594247: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 14:17:07.031205: lr: 0.009458
# 2025-10-19 14:17:09.335784: saving checkpoint...
# 2025-10-19 14:17:25.020258: done, saving took 17.74 seconds
# 2025-10-19 14:17:25.142338: This epoch took 1096.624401 s
#
# 2025-10-19 14:17:25.173763:
# epoch:  3
# 2025-10-19 14:33:14.533322: train loss : -0.3166
# 2025-10-19 14:33:56.409656: validation loss: -0.1558
# 2025-10-19 14:33:56.519141: Average global foreground Dice: [np.float32(0.1536), np.float32(0.6996), np.float32(0.6558), np.float32(0.684)]
# 2025-10-19 14:33:56.632018: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 14:34:02.978273: lr: 0.009277
# 2025-10-19 14:34:04.147371: saving checkpoint...
# 2025-10-19 14:34:18.764242: done, saving took 15.71 seconds
# 2025-10-19 14:34:18.864991: This epoch took 1013.633812 s
#
# 2025-10-19 14:34:18.903826:
# epoch:  4
# 2025-10-19 14:51:13.125643: train loss : -0.3448
# 2025-10-19 14:51:52.272044: validation loss: -0.1683
# 2025-10-19 14:51:52.416659: Average global foreground Dice: [np.float32(0.1772), np.float32(0.8089), np.float32(0.706), np.float32(0.5455)]
# 2025-10-19 14:51:52.543557: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 14:52:01.334389: lr: 0.009095
# 2025-10-19 14:52:04.423156: saving checkpoint...
# 2025-10-19 14:52:22.670193: done, saving took 21.10 seconds
# 2025-10-19 14:52:22.962644: This epoch took 1084.017308 s
#
# 2025-10-19 14:52:23.056165:
# epoch:  5
# 2025-10-19 15:08:02.693019: train loss : -0.3636
# 2025-10-19 15:08:39.190528: validation loss: -0.1994
# 2025-10-19 15:08:39.355324: Average global foreground Dice: [np.float32(0.303), np.float32(0.67), np.float32(0.7212), np.float32(0.7061)]
# 2025-10-19 15:08:39.455904: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 15:08:48.211438: lr: 0.008913
# 2025-10-19 15:08:49.459652: saving checkpoint...
# 2025-10-19 15:09:08.604103: done, saving took 20.26 seconds
# 2025-10-19 15:09:08.874442: This epoch took 1005.678547 s
#
# 2025-10-19 15:09:09.017083:
# epoch:  6
# 2025-10-19 15:27:14.460232: train loss : -0.3905
# 2025-10-19 15:27:55.459562: validation loss: -0.1944
# 2025-10-19 15:27:55.561312: Average global foreground Dice: [np.float32(0.2906), np.float32(0.8112), np.float32(0.7558), np.float32(0.5268)]
# 2025-10-19 15:27:55.674290: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2025-10-19 15:28:01.993444: lr: 0.008731
# 2025-10-19 15:28:03.198866: saving checkpoint...
# 2025-10-19 15:28:26.099670: done, saving took 24.05 seconds
# 2025-10-19 15:28:26.535235: This epoch took 1157.400223 s
#
# 2025-10-19 15:28:26.626707:
# epoch:  7

# %%
import os
os.path.exists('/content/drive/MyDrive/TCC_1/1.Data/nnU-net_format/subset_50/nnUNet_preprocessed/Task001_MyBraTS/nnUNetData_plans_v2.1_stage0/BraTS-GLI-02817-100.npz')
