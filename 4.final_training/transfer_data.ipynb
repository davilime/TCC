# %%
# !apt-get install -y google-cloud-sdk
from google.colab import auth
auth.authenticate_user()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package google-cloud-sdk

# %%
# !gcloud projects describe brats-final-training
# Out:
# createTime: '2025-11-10T00:32:18.762549Z'
# lifecycleState: ACTIVE
# name: BraTS-final-training
# projectId: brats-final-training
# projectNumber: '118647584913'

# %%
# !gcloud config set project brats-final-training
# Out:
# INFORMATION: Project 'brats-final-training' has no 'environment' tag set. Use either 'Production', 'Development', 'Test', or 'Staging'. Add an 'environment' tag using `gcloud resource-manager tags bindings create`.
# Updated property [core/project].

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gsutil -m cp -r "/content/drive/MyDrive/TCC" gs://brats-final-training/
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Copying file:///content/drive/MyDrive/TCC/1.Data/BraTS-GLI/brats2024-brats-gli-trainingdata/training_data1_v2/BraTS-GLI-00006-100/BraTS-GLI-00006-100-seg.nii.gz [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/TCC/1.Data/BraTS-GLI/brats2024-brats-gli-trainingdata/training_data1_v2/BraTS-GLI-00006-101/BraTS-GLI-00006-101-t2f.nii.gz [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/TCC/1.Data/BraTS-GLI/brats2024-brats-gli-trainingdata/training_data1_v2/BraTS-GLI-00006-101/BraTS-GLI-00006-101-t1c.nii.gz [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/TCC/1.Data/BraTS-GLI/brats2024-brats-gli-trainingdata/training_data1_v2/BraTS-GLI-00008-100/BraTS-GLI-00008-100-t1n.nii.gz [Content-Type=application/octet-stream]...
# ...

# %%
# !gsutil mb -l us-central1 gs://brats-final-training
# Out:
# Creating gs://brats-final-training/...
# ServiceException: 409 A Cloud Storage bucket named 'brats-final-training' already exists. Try another name. Bucket names must be globally unique across all Google Cloud projects, including those outside of your organization.
